# %%
import cv2
import numpy as np
import subprocess as sb

# %%
shape = int(input('Enter the shape of photo : '))
# Out:
# Enter the shape of photo : 224

# %%
name = input('Enter your name (without space) to label the image folder : ')
# Out:
# Enter your name (without space) to label the image folder : niilam

# %%
def fliph(photo):
    ifliph = np.zeros(photo.shape).astype('uint8')
    for i in range(0,photo.shape[0]):
        ifliph[photo.shape[0]-i-1,:] = photo[i,:]
    return ifliph

def flipv(photo):
    iflipv = np.zeros(photo.shape).astype('uint8')
    for i in range(0,photo.shape[0]):
        iflipv[:,i] = photo[:,photo.shape[0]-i-1]
    return iflipv

def r270(photo):
    iflip270 = np.zeros(photo.shape).astype('uint8')
    for i in range(0,photo.shape[0]):
        iflip270[photo.shape[0]-i-1,:] = photo[:,i]
    return iflip270

# %% [markdown]
# # Create these folders :
#     1)dataset
#     2)within dataset two folders :
#         a)test
#         b)train
#     3)within both test and train create folder of your name (which you have specified above)
# Note : Create folders as it is , the images will b transferred directly to these folders because

# %%
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
def face_extractor(photo):
    cord = face_classifier.detectMultiScale(photo)    
    if cord is ():
        return None
    photo = cv2.resize(photo,(shape,shape))
    return photo

cap = cv2.VideoCapture(0)
count = 0

# Collect 200 samples of your face from webcam input to make 1600 images
while True:
    status , photo = cap.read()
    print(status)
    if status == True:
        photo = face_extractor(photo)
        if photo is not None:
            
            scount = count*8 + 1  #for one photo will become 8 photos
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,photo)

            scount += 1
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,fliph(photo))

            scount += 1
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,flipv(photo))

            scount += 1
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,r270(photo))

            scount += 1
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,fliph(r270(photo)))

            scount += 1
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,flipv(r270(photo)))

            scount += 1
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,fliph(flipv(r270(photo))))

            scount += 1
            file_name_path = './dataset/train/{}/image'.format(name) + str(scount) + '.jpg'
            cv2.imwrite(file_name_path,flipv(fliph(photo)))
            
            count += 1

            # Put count on images and display live count
            cv2.putText(photo, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Display', photo)

        else:
            print("Face not found")
            pass

        if cv2.waitKey(1) == 27 or count == 200: #27 is the Escape Key
            break
            

cap.release()
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# Face not found
# True
# True
# Face not found
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
#Moving 400 images from train to test database

#generate random 400 numbers from 1 to 1600
test = np.random.randint(low=1, high=1600, size=400)
for i in range(0,350):
    command = 'mv ./dataset/train/{}/image'.format(name) + str(test[i]) + '.jpg ' + './dataset/test/' + name
    #print(command)
    #command is 'mv source_file destination_folder'
    #change above command as per your os
    sb.getoutput(command)

print("Generating Database complete")
# Out:
# Generating Database complete
